# %% [markdown]
# ## input

# %%
input
# Out:
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x0000028615D2D160>>

# %%
input()
# Out:
#  hari
# 'hari'

# %%
input()
# Out:
#  hari
# 'hari'

# %%
input()
# Out:
#  dd
# 'dd'

# %%
input()
input()
input()
# Out:
#  dfgh
#  fgh
#  dfgh
# 'dfgh'

# %%
name=input()
# Out:
#  hari

# %%
print(name)
# Out:
# hari

# %%
age=input()
# Out:
# 22 fd

# %%
age
# Out:
# 'fd'

# %%
name=input("enetr your name:")
age=input("Enter your age;")
city= input("enter your city:")
print('')
# Out:
# enetr your name: hari
# Enter your age; 33

# %%
- ** syntax error**`

# %% [markdown]
# - **syntax error**`

# %% [markdown]
# **Note**
# - when we provide a value from keyboard python takes string data type

# %%
name=input()
age=input()
city=input()
print(f"my name is {name},my age is {age},i came from city is {city}.format(name,age,city))
# Out:
#   Cell In[2], line 4
#     print(f"my name is {name},my age is {age},i came from city is {city}.format(name,age,city))
#           ^
# SyntaxError: unterminated f-string literal (detected at line 4)

# %%
name=input()
age=input()
city=input()
print(f"my name is {name},my age is {age},i came from city is {city}")
# Out:
#  hari
#  22
#  usa
# my name is hari,my age is 22,i came from city is usa

# %% [markdown]
# - **syntax error**
#
#     - python exception from you is provide a proper code
#
#     - when you are not write a proper code

# %% [markdown]
# **Note**
#
# - when we provide a value from keyboard
#
# - by defualt python takes **string data type**

# %%
n1=input('enter a number 1:')
n2=input('enetr a number 2:')
n1+n2
# Out:
# enter a number 1: 100
# enetr a number 2: 200
# '100200'

# %% [markdown]
# **type casting**
#
#   - convert one data type to another data type
#
#   - int, float,str,bool
#
#   -  if a user provide one data type we can conveet in to another data type is called type casting.

# %% [markdown]
# **integer to other data types**

# %%
n1=100
float(n1)
# Out:
# 100.0

# %%
n1=100
str(n1)
# Out:
# '100'

# %%
n1=100
bool(n1)
# Out:
# True

# %%
float(100),str(100),bool(100)
# Out:
# (100.0, '100', True)

# %%
bool(0)
# Out:
# False

# %%
bool()
# Out:
# False

# %% [markdown]
# **float to other data type**

# %%
int(10.5),str(10.5),bool(10.5)
# Out:
# (10, '10.5', True)

# %%
int(10.5),str(10.5),bool(0.00)
# Out:
# (10, '10.5', False)

# %%
int(-10.5),str(-10.5),bool(-10.5)
# Out:
# (-10, '-10.5', True)

# %%
int(0.0),str(0.0),bool(0)
# Out:
# (0, '0.0', False)

# %% [markdown]
# **string to other data type**

# %%
s1="apple"
s2="100"
s3="100.3"
int(s1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 4
#       2 s2="100"
#       3 s3="100.3"
# ----> 4 int(s1)
#
# ValueError: invalid literal for int() with base 10: 'apple'

# %%
s1="apple"
s2="100"
s3="100.3"
int(s2)
# Out:
# 100

# %%
s1="apple"
s2="100"
s3="100.3"
int(s3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 4
#       2 s2="100"
#       3 s3="100.3"
# ----> 4 int(s3)
#
# ValueError: invalid literal for int() with base 10: '100.3'

# %%
float(s1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 float(s1)
#
# ValueError: could not convert string to float: 'apple'

# %%
bool(s1)
# Out:
# True

# %%
s2='100'
int(s2)
# Out:
# 100

# %%
float(s2)
# Out:
# 100.0

# %%
bool(s2)
# Out:
# True

# %%
int('10.5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 int('10.5')
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
float('10.5')
# Out:
# 10.5

# %%
bool('10.5')
# Out:
# True

# %%
int(100.5)
# Out:
# 100

# %%
int('100.5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 int('100.5')
#
# ValueError: invalid literal for int() with base 10: '100.5'

# %%
bool('')
# Out:
# False

# %%
bool('  ')
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
a=0
bool(a)
# Out:
# False

# %%
int(100),int('100.3')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 int(100),int('100.3')
#
# ValueError: invalid literal for int() with base 10: '100.3'

# %% [markdown]
# **boolen to other**

# %%
int(True)
float(True)
str('True')
# Out:
# 'True'

# %%
int(True)
# Out:
# 1

# %%
float(True)
# Out:
# 1.0

# %%
bool(True)
# Out:
# True

# %%
n1=int(input('enetr the n1:'))
n2=int(input('enter the n2:'))

n1+n2
# Out:
# enetr the n1: 199
# enter the n2: 199
# 398

# %%
n1=float(input('enter a number n1:'))
n2=float(input('enetr a number n2:'))
n1+n2
# Out:
# enter a number n1: 100
# enetr a number n2: 12.22
# 112.22

# %% [markdown]
# - whenever we want to use integer then we are applying int
#
# - similarly if we want to use decimal number we are applying **float**
#
# - there is one more operation is there:**eval**
#
# - **eval** will convert integers values to int type,decimal values to float type

# %%
eval('12.33')
# Out:
# 12.33

# %%
n1=eval(input('enetr a number n1:'))
n2=eval(input('enter a number n2'))
n1+n2
# Out:
# enetr a number n1: 100
# enter a number n2 100.2
# 200.2

# %%
n1=eval(input('enetr first number:'))
n2=eval(input('enter second number:'))
n3=eval(input('enetr third number:'))
avg=(n1+n2+n3)/3
print(f"average of three numbers are {round(avg,4)}")
# Out:
# enetr first number: 100.33
# enter second number: 122.44
# enetr third number: 433.44
# average of three numbers are 218.7367
