# %% [markdown]
# - print is an inbuilt function used to print the output
#
# - we always work towards only one end goal: **customer satisfaction**
#
# - Client does not know the python code
#
# - what ever we want to show the output we need to display very clearly
#
# - Question yourself : **AM I SHOWING IT PROPERLY**

# %%
n1=100
n2=200
add=n1+n2
print('the addition of 100 and 200 is 300')
# Out:
# the addition of 100 and 200 is 300

# %%
n1=100
n2=200
add=n1+n2
print('the addition of n1 and n2 is add')
# Out:
# the addition of n1 and n2 is add

# %%
n1=100
n2=200
add=n1+n2
print('the addition of',n1,'and',n2,'is', add)
# Out:
# the addition of 100 and 200 is 300

# %%
name="hari"
age=29
place="usa"
print('I am',name,age,'years old coming from',place)
# Out:
# I am hari 29 years old coming from usa

# %%
name="hari"
age=29
place="usa"
print(" I am {} with {} years old live in {}".format(name,age,place))
# Out:
#  I am hari with 29 years old live in usa

# %% [markdown]
# **f-string**
#
# - very easy and most used one

# %%
n1=100
n2=200
add=n1+n2
print(f'The addition of {n1} and {n2} = {add}')
# Out:
# The addition of 100 and 200 = 300

# %%
n1=int(input("enetr first value:   "))
n2=int(input("enter second value:  "))
sum=n1+n2
print("Sum of {} and {} = {}".format(n1,n2,sum))
# Out:
# enetr first value:    150
# enter second value:   250
# Sum of 150 and 250 = 400

# %%
pi=3.14
radiius=100
area_of_circle=pi*radiius*radiius
print('area of circle with radius "{}" is {}'.format(radiius,area_of_circle))
# Out:
# area of circle with radius "100" is 31400.0

# %%
print()

# %% [markdown]
# **round off**

# %%
a=10
b=21
c=30
avg=(a+b+c)/3
print(avg)
# Out:
# 20.333333333333332

# %%
round(12.3444)
# Out:
# 12

# %%
round(12.789)
# Out:
# 13

# %%
round(12.7899,2)
# Out:
# 12.79

# %%
a=10
b=21
c=30
avg=(a+b+c)/3
ro=round(avg,2)
print(f"the average of three numbers is {ro}")
# Out:
# the average of three numbers is 20.33

# %%
print()
type()
max()
sum()
len()
round()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 print()
# ----> 2 type()
#       3 max()
#       4 sum()
#
# TypeError: type() takes 1 or 3 arguments

# %% [markdown]
# # () function call or method call
# # whenever we miss the brackets
# # it will indicates in two ways

# %% [markdown]
# - bound method
#
# - function

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\hariv\\OneDrive\\Documents\\Naresh it\\python\\python sessions'
