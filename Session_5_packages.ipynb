# %% [markdown]
# - varibles
#
# - data types
#
# - type casting
#
# - print statments
#
# - input and round
#
# - we prerform the basic code

# %%
import addition
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import addition
#
# ModuleNotFoundError: No module named 'addition'

# %%
import random

# %%
import math

# %%
import time

# %%
import os

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %% [markdown]
# **Module**
#
# - Module is a single Python file
#
# - having variables, functions, classes, methods
#
# **packages**
#
# - The package contains multiple Python files
#
# - Assume that Rames has created 4 Python files
#     - add.py
#     - sub.py
#     - mul.py
#     - div.py
#
# - All these 4 python files can save in to packages

# %%
math_function/
    add.py
    sub.py
    mul.py
    div.py

from math_function import add
from math_function import sub
from math_function import mul
from math_function import div

# %% [markdown]
# **random**

# %%
import random
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
# step -1: import module
# step-2: dir()
import random
import math

# %% [markdown]
# **methods under a module also called as attributes**
#
# - random is a module
#
#     - randint is method or attribute
#
#
# - Every method purpose is different the use case is different
#
# - if we want to call method or attribute, we need to call using module  only

# %%
import random
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x0000021EEBE7D9F0>>

# %%
import random
random.randint()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 import random
# ----> 2 random.randint()
#
# TypeError: Random.randint() missing 2 required positional arguments: 'a' and 'b'

# %%
import random
random.hari
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 import random
# ----> 2 random.hari
#
# AttributeError: module 'random' has no attribute 'hari'

# %%
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
import random
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x0000021EEBE7D9F0>>

# %%
import random
random.randint()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 import random
# ----> 2 random.randint()
#
# TypeError: Random.randint() missing 2 required positional arguments: 'a' and 'b'

# %%
import random
#dir(random)
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x0000021EEBE7D9F0>>

# %%
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
import random
random.randint(10,20)
# Out:
# 14

# %%
import random
#dir(random)
random.randint
help(random.randint)
random.randint(1,10)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.
# 3

# %%
import random
random.random
# Out:
# <function Random.random()>

# %%
import random
help(random.random)
# Out:
# Help on built-in function random:
#
# random() method of random.Random instance
#     random() -> x in the interval [0, 1).

# %%
import random
random.random()
# Out:
# 0.6060851839595304

# %%
import random
l=[10,20,30,40,50]
random.choice(l)
# Out:
# 50

# %%
l=[ ]
random.shuffle()

# %%
import math
#a="34"
help(math.e())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 import math
#       2 #a="34"
# ----> 3 help(math.e())
#
# TypeError: 'float' object is not callable

# %%
pi=3.14
math.pi(pi)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 pi=3.14
# ----> 2 math.pi(pi)
#
# TypeError: 'float' object is not callable

# %%
math.sqrt(10)
# Out:
# 3.1622776601683795

# %%
import random
l=[10,20,30,40,50]
random.shuffle(l)
print(l)
# Out:
# [50, 40, 30, 10, 20]

# %%
math.sqrt(10)
# Out:
# 3.1622776601683795

# %%
math.pow(10,2)
# Out:
# 100.0

# %%
math.sin(10)
# Out:
# -0.5440211108893698

# %%
math.pi(567.567)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 math.pi(567.567)
#
# TypeError: 'float' object is not callable

# %%
math.ceil()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 math.ceil()
#
# TypeError: math.ceil() takes exactly one argument (0 given)

# %%
import time
time.sleep(1)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\hariv\\OneDrive\\Documents\\Naresh it\\python\\python sessions'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'assignment_2.ipynb',
#  'assignment_3.ipynb',
#  'own_python _practice _notes.ipynb',
#  'python_assignments',
#  'session_1.ipynb',
#  'session_1_varibles.ipynb',
#  'session_2_data_types.ipynb',
#  'Session_3_print_statement.ipynb',
#  'session_4input_eval_statements.ipynb',
#  'Session_5_packages.ipynb']

# %%
import math
math.e()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 2
#       1 import math
# ----> 2 math.e()
#
# TypeError: 'float' object is not callable

# %%
import math
math.e
# Out:
# 2.718281828459045

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(10)
# Out:
# 3.1622776601683795

# %%
math.pow(10,2)
# Out:
# 100.0

# %%
x=20
math.ceil(x)
# Out:
# 20

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\hariv\\OneDrive\\Documents\\Naresh it\\python\\python sessions'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'assignment_2.ipynb',
#  'assignment_3.ipynb',
#  'own_python _practice _notes.ipynb',
#  'python_assignments',
#  'session_1.ipynb',
#  'session_1_varibles.ipynb',
#  'session_2_data_types.ipynb',
#  'Session_3_print_statement.ipynb',
#  'session_4input_eval_statements.ipynb',
#  'Session_5_packages.ipynb']

# %%
math.ceil(4567.5678)
# Out:
# 4568

# %%
import time
time.sleep(10)
print("hi ")
# Out:
# hi

# %%
import time
dir(time)
# Out:
# ['_STRUCT_TM_ITEMS',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'altzone',
#  'asctime',
#  'ctime',
#  'daylight',
#  'get_clock_info',
#  'gmtime',
#  'localtime',
#  'mktime',
#  'monotonic',
#  'monotonic_ns',
#  'perf_counter',
#  'perf_counter_ns',
#  'process_time',
#  'process_time_ns',
#  'sleep',
#  'strftime',
#  'strptime',
#  'struct_time',
#  'thread_time',
#  'thread_time_ns',
#  'time',
#  'time_ns',
#  'timezone',
#  'tzname']

# %%
os.makedir
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 os.makedir
#
# AttributeError: module 'os' has no attribute 'makedir'

# %%
import os
os.makedirs()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 2
#       1 import os
# ----> 2 os.makedirs()
#
# TypeError: makedirs() missing 1 required positional argument: 'name'

# %%
os.listdir()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 os.listdir()
#
# NameError: name 'os' is not defined

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'assignment_2.ipynb',
#  'assignment_3.ipynb',
#  'own_python _practice _notes.ipynb',
#  'python_assignments',
#  'session_1.ipynb',
#  'session_1_varibles.ipynb',
#  'session_2_data_types.ipynb',
#  'Session_3_print_statement.ipynb',
#  'session_4input_eval_statements.ipynb',
#  'Session_5_packages.ipynb']

# %%
os.makedirs()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 os.makedirs()
#
# TypeError: makedirs() missing 1 required positional argument: 'name'

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# **we understood the modules and packages**
#
# **we understood the difference between functions and methods**
#
# **import <module_name>**
#
# **dir<modele_name>**
#
#     _ methods
#
#     - functions
#
#     - attributes
#
# **module_name.attributes_name**
#
#      - is it providing direct answer
#
#
#      - function outside the class
#
#
#     - bound method inside the class
#
#
# **help(module_name.attribute_name)**
#
#
# **arguments are available are not**

# %%
import string
dir(string)
string.ascii_uppercase
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
string.digits
# Out:
# '0123456789'

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
string.ascii_letters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
from random import randint
randint(10,20)
# Out:
# 15

# %%
import random
random
# Out:
# <module 'random' from 'C:\\Users\\hariv\\anaconda3\\Lib\\random.py'>

# %%
import flask

# %%
import streamlit

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
import langchain

# %%
import virat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import virat
#
# ModuleNotFoundError: No module named 'virat'

# %%
import langchain

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
pip install cv2
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2

# %%
pip install cv2
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2

# %%
# !pip install cv2
# Out:
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2

# %%
pip install cv2
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2

# %%
0,0
# Out:
# (0, 0)

# %%
pip install CV2
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement CV2 (from versions: none)
# ERROR: No matching distribution found for CV2

# %%
pip install cv2
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement cv2 (from versions: none)
# ERROR: No matching distribution found for cv2

# %%
# !pip install opencv-python

# %%
import cv2

# %%
import langchain

# %%
import cv2

# %%
import langgraph

# %%
import tensorflow

# %%
pip freeze
# Out:
# absl-py==2.3.1
# aext-assistant @ file:///C:/b/abs_1bfn_ondsd/croot/aext-assistant_1746560154452/work
# aext-assistant-server @ file:///C:/b/abs_6f6umrladb/croot/aext-assistant-server_1746552992573/work
# aext-core @ file:///C:/b/abs_a0497039ax/croot/aext-core_1746546102863/work
# aext-core-server @ file:///C:/b/abs_82tjab_7w4/croot/aext-core-server_1746542360244/work
# aext-panels @ file:///C:/b/abs_fde530cwui/croot/aext-panels_1746560097533/work
# aext-panels-server @ file:///C:/b/abs_6672ttq6cc/croot/aext-panels-server_1746552976245/work
# aext-project-filebrowser-server @ file:///C:/b/abs_79l9wkmqos/croot/aext-project-filebrowser-server_1746563508758/work/backend_lib/project_filebrowser
# aext-share-notebook @ file:///C:/b/abs_4dnd8bg_5y/croot/aext-share-notebook_1746556779074/work
# aext-share-notebook-server @ file:///C:/b/abs_33583xtbk0/croot/aext-share-notebook-server_1746552715592/work
# aext-shared @ file:///C:/b/abs_4fe5it0ngg/croot/aext-shared_1746540522892/work
# ...

# %%
pip freeze
# Out:
# absl-py==2.3.1
# aext-assistant @ file:///C:/b/abs_1bfn_ondsd/croot/aext-assistant_1746560154452/work
# aext-assistant-server @ file:///C:/b/abs_6f6umrladb/croot/aext-assistant-server_1746552992573/work
# aext-core @ file:///C:/b/abs_a0497039ax/croot/aext-core_1746546102863/work
# aext-core-server @ file:///C:/b/abs_82tjab_7w4/croot/aext-core-server_1746542360244/work
# aext-panels @ file:///C:/b/abs_fde530cwui/croot/aext-panels_1746560097533/work
# aext-panels-server @ file:///C:/b/abs_6672ttq6cc/croot/aext-panels-server_1746552976245/work
# aext-project-filebrowser-server @ file:///C:/b/abs_79l9wkmqos/croot/aext-project-filebrowser-server_1746563508758/work/backend_lib/project_filebrowser
# aext-share-notebook @ file:///C:/b/abs_4dnd8bg_5y/croot/aext-share-notebook_1746556779074/work
# aext-share-notebook-server @ file:///C:/b/abs_33583xtbk0/croot/aext-share-notebook-server_1746552715592/work
# aext-shared @ file:///C:/b/abs_4fe5it0ngg/croot/aext-shared_1746540522892/work
# ...
